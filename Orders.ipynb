# %%
import boto3
import pandas as pd
import io

# %%
s3 = boto3.resource("s3")
bucket = s3.Bucket("??")
prefix_objs = bucket.objects.filter(Prefix="??")

df = None
for obj in prefix_objs:
    key = obj.key
    body = obj.get()['Body'].read()
    if df is None:
        df = pd.read_csv(io.BytesIO(body), encoding='utf8')
    else:
        df = pd.concat([df, pd.read_csv(io.BytesIO(body), encoding='utf8')], ignore_index=True)

# %%
df.head()
# Out:
#    Unnamed: 0        LatestShipDate      OrderType              PurchaseDate  \
# 0           0  2020-01-03T07:59:59Z  StandardOrder  2020-01-01T00:04:03.448Z
# 1           1  2020-02-12T07:59:59Z  StandardOrder  2020-01-01T00:04:38.033Z
# 2           2  2020-01-05T07:59:59Z  StandardOrder  2020-01-01T00:06:26.466Z
# 3           3  2020-01-02T07:59:59Z  StandardOrder  2020-01-01T00:09:18.293Z
# 4           4  2020-01-07T07:59:59Z  StandardOrder  2020-01-01T00:09:20.202Z
#
#          AmazonOrderId                              BuyerEmail  \
# 0  112  @marketplace.amazon.com
# 1  113  @marketplace.amazon.com
# 2  112  @marketplace.amazon.com
# 3  111  @marketplace.amazon.com
# 4  111                                     NaN
#
#              LastUpdateDate  IsReplacementOrder  NumberOfItemsShipped  \
# 0  2020-01-02T18:06:14.063Z               False                     1
# 1  2020-01-02T20:33:43.092Z               False                     1
# 2  2020-01-02T23:15:52.111Z               False                     1
# 3  2020-01-03T17:42:38.915Z               False                     1
# 4  2020-01-01T00:12:29.758Z               False                     0
#
#   ShipServiceLevel  ... LatestDeliveryDate EarliestDeliveryDate  \
# 0        Expedited  ...                NaN                  NaN
# 1         Standard  ...                NaN                  NaN
# 2        Expedited  ...                NaN                  NaN
# 3        Expedited  ...                NaN                  NaN
# 4         Standard  ...                NaN                  NaN
#
#    DefaultShipFromLocationAddress.City  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    DefaultShipFromLocationAddress.PostalCode  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    DefaultShipFromLocationAddress.isAddressSharingConfidential  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    DefaultShipFromLocationAddress.StateOrRegion  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    DefaultShipFromLocationAddress.CountryCode  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   DefaultShipFromLocationAddress.Name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   DefaultShipFromLocationAddress.AddressLine1  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   DefaultShipFromLocationAddress.AddressLine2
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 47 columns]
